# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')
df.head()

# %%
df.shape

# %%
df.dtypes

# %%
df.columns

# %%
df.index

# %%
df.info()

# %%
df.describe()

# %%
df.duplicated().sum()

# %%
a=[]
for i in df:
    if df[i].isnull().sum()>df.shape[0]/2:
        a.append(i)
len(a)

# %%
df1=df.drop(a,axis=1)

# %%
df1.head()

# %%
df1.shape

# %%
i=[i.split('_')[0] for i in df.columns]

# %%
df.loc[0]['Q38_B_Part_2']

# %%
def multiple_choice(Qn):
    Qn_colsA=list(filter(lambda x:(x.split('_')[0]==Qn and x.split('_')[1]=='A'),df.columns))
    Qn_colsB=list(filter(lambda x:(x.split('_')[0]==Qn and x.split('_')[1]=='B'),df.columns))
    Qn_cols=list(filter(lambda x: x.split('_')[0]==Qn ,df.columns))
    count={}
    a={}
    for q in Qn_colsA:
        a[q]=df.loc[df[q].notnull(),q].unique()[1]
        count[q]=df[q].count()-1
    print(a)
    b={}
    for q in Qn_colsB:
        b[q]=df.loc[df[q].notnull(),q].unique()[1]
        count[q]=df[q].count()-1
    print(b)
    if not a and not b:
        c={}
        for q in Qn_cols:
            c[q]=df.loc[df[q].notnull(),q].unique()[1]
            count[q]=df[q].count()-1
        print(c)
    print(count)
        
    
multiple_choice('Q9')

# %%
df.columns.tolist()
