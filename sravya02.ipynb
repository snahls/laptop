# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing dataset
df=pd.read_csv('../input/kaggle-survey-2021/kaggle_survey_2021_responses.csv')

# %%
#Get Top 5 rows
df.head()

# %%
#Set visible columns to 500
pd.set_option('display.max_columns',500)

# %%
#Now get Top 5 rows
df.head()

# %%
#Information about dataset
df.info()

# %%
#Summarize dataset
df.describe()

# %%
#Get columns
df.columns

# %%
#Get columns as list
df.columns.tolist()

# %%
#Check for duplicates
df.duplicated().sum()

# %%
#Get Percentage of Null values in each column
df.isnull().sum()/df.shape[0]*100

# %%
#Get the count of columns with more than 98% Null values
a=[]
for i in df:
    if df[i].isnull().sum()>(df.shape[0]*0.98):
        a.append(i)
len(a)

# %%
#Drop columns with more than 98% Null values
df1=df.drop(a,axis=1)

# %%
#Get Top 5 rows
df1.head()

# %%
#Get columns
df1.columns

# %%
#Get columns as list
df1.columns.tolist()

# %%
#Summarize
df1.describe()

# %%
#Get questions
df_Q=df1.iloc[:1]

# %%
#Questions dataset
df_Q

# %%
#Dataset with no questions
df_NoQ=df1.iloc[1:]

# %%
#Check datatypes
df_NoQ.dtypes

# %%
#Sort according to unique values in each column
df_NoQ.nunique().sort_values()

# %% [markdown]
# Question-1 (Q1)

# %%
df_NoQ['Q1'].value_counts()

# %%
df_Q['Q1']

# %% [markdown]
# Majority responses are from Age group 18-29
#
# Also with Age increasing responses decreased

# %%
sns.countplot(x='Q1',data=df_NoQ,order=df_NoQ['Q1'].value_counts().sort_index().index)

# %% [markdown]
# Question-2 (Q2)

# %%
df_NoQ['Q2'].value_counts()

# %%
df_Q['Q2']

# %% [markdown]
# Majority responses are from Man

# %%
plt.pie(df_NoQ['Q2'].value_counts(),labels=df_NoQ['Q2'].value_counts().index,explode=[0,0,0.4,0.2,0.1],startangle=90)
plt.legend()
plt.show()

# %% [markdown]
# Question-3 (Q3)

# %%
df_NoQ['Q3'].value_counts()

# %%
df_Q['Q3']

# %% [markdown]
# Majority responses are from India

# %%
l=sns.countplot(x='Q3',data=df_NoQ,order=df_NoQ['Q3'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q3'].value_counts().sort_index().index,rotation=90,fontsize=6)
plt.show()

# %% [markdown]
# Question-4 (Q4)

# %%
df_NoQ['Q4'].value_counts()

# %%
df_Q['Q4']

# %% [markdown]
# Majority responses are from people who has highest level as Master's degree followed by people who has highest level as Bachelor's degree

# %%
l=sns.countplot(x='Q4',data=df_NoQ,order=df_NoQ['Q4'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q4'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
l=sns.countplot(x='Q4',data=df_NoQ,order=df_NoQ['Q4'].value_counts().sort_index().index,hue=df_NoQ['Q2'])
l.set_xticklabels(labels=df_NoQ['Q4'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Man responses dominated woman in every degree

# %% [markdown]
# Question-5 (Q5)

# %%
df_NoQ['Q5'].value_counts()

# %%
df_Q['Q5']

# %% [markdown]
# Majority responses are from students

# %%
l=sns.countplot(x='Q5',data=df_NoQ,order=df_NoQ['Q5'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q5'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
l=sns.countplot(x='Q5',data=df_NoQ,order=df_NoQ['Q5'].value_counts().sort_index().index,hue=df_NoQ['Q2'])
l.set_xticklabels(labels=df_NoQ['Q5'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Man responses dominated woman in every field

# %% [markdown]
# Question-6 (Q6)

# %%
df_NoQ['Q6'].value_counts()

# %%
df_Q['Q6']

# %% [markdown]
# Majority people started writing code in between 1-3 years

# %%
l=sns.countplot(x='Q6',data=df_NoQ,order=df_NoQ['Q6'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q6'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
l=sns.countplot(x='Q6',data=df_NoQ,order=df_NoQ['Q6'].value_counts().sort_index().index,hue=df_NoQ['Q2'])
l.set_xticklabels(labels=df_NoQ['Q6'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Man dominated woman every time

# %% [markdown]
# Question-7 (Q7)

# %%
df_Q['Q7_Part_1']

# %%
Q7_parts=list(filter(lambda x: x.split('_')[0]=='Q7' ,df_NoQ.columns))
dfQ7=pd.DataFrame(df_NoQ[Q7_parts].stack().tolist(),columns=['Languages'])
dfQ7['Languages'].value_counts()

# %% [markdown]
# Majority use python programming language

# %%
l=sns.countplot(x='Languages',data=dfQ7,order=dfQ7['Languages'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ7['Languages'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-8 (Q8)

# %%
df_NoQ['Q8'].value_counts()

# %%
df_Q['Q8']

# %% [markdown]
# Majority recommend python programming language

# %%
l=sns.countplot(x='Q8',data=df_NoQ,order=df_NoQ['Q8'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q8'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
l=sns.countplot(x='Q8',data=df_NoQ,order=df_NoQ['Q8'].value_counts().sort_index().index,hue=df_NoQ['Q2'])
l.set_xticklabels(labels=df_NoQ['Q8'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Man dominantly recommended python than woman

# %% [markdown]
# Question-9 (Q9)

# %%
df_Q['Q9_Part_1']

# %%
Q9_parts=list(filter(lambda x: x.split('_')[0]=='Q9' ,df_NoQ.columns))
dfQ9=pd.DataFrame(df_NoQ[Q9_parts].stack().tolist(),columns=['IDEs'])
dfQ9['IDEs'].value_counts()

# %% [markdown]
# Majority use Jupyter Notebook IDE

# %%
l=sns.countplot(x='IDEs',data=dfQ9,order=dfQ9['IDEs'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ9['IDEs'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-10 (Q10)

# %%
df_Q['Q10_Part_1']

# %%
Q10_parts=list(filter(lambda x: x.split('_')[0]=='Q10' ,df_NoQ.columns))
dfQ10=pd.DataFrame(df_NoQ[Q10_parts].stack().tolist(),columns=['Notebooks'])
dfQ10['Notebooks'].value_counts()

# %% [markdown]
# Majority use Colab followed by kaggle notebooks

# %%
l=sns.countplot(x='Notebooks',data=dfQ10,order=dfQ10['Notebooks'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ10['Notebooks'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-11 (Q11)

# %%
df_NoQ['Q11'].value_counts()

# %%
df_Q['Q11']

# %% [markdown]
# Majority use Laptop

# %%
l=sns.countplot(x='Q11',data=df_NoQ,order=df_NoQ['Q11'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q11'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-12 (Q12)

# %%
df_Q['Q12_Part_1']

# %%
Q12_parts=list(filter(lambda x: x.split('_')[0]=='Q12' ,df_NoQ.columns))
dfQ12=pd.DataFrame(df_NoQ[Q12_parts].stack().tolist(),columns=['Hardware'])
dfQ12['Hardware'].value_counts()

# %% [markdown]
# Majority use NVIDIA GPUs

# %%
l=sns.countplot(x='Hardware',data=dfQ12,order=dfQ12['Hardware'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ12['Hardware'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-13 (Q13)

# %%
df_NoQ['Q13'].value_counts()

# %%
df_Q['Q13']

# %% [markdown]
# Majority never used TPU

# %%
l=sns.countplot(x='Q13',data=df_NoQ,order=df_NoQ['Q13'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q13'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-14 (Q14)

# %%
df_Q['Q14_Part_1']

# %%
Q14_parts=list(filter(lambda x: x.split('_')[0]=='Q14' ,df_NoQ.columns))
dfQ14=pd.DataFrame(df_NoQ[Q14_parts].stack().tolist(),columns=['Visualization'])
dfQ14['Visualization'].value_counts()

# %% [markdown]
# Majority use Matplotlib for Visualization

# %%
l=sns.countplot(x='Visualization',data=dfQ14,order=dfQ14['Visualization'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ14['Visualization'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-15 (Q15)

# %%
df_NoQ['Q15'].value_counts()

# %%
df_Q['Q15']

# %% [markdown]
# Majority used ML under 1 year

# %%
l=sns.countplot(x='Q15',data=df_NoQ,order=df_NoQ['Q15'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q15'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-16 (Q16)

# %%
df_Q['Q16_Part_1']

# %%
Q16_parts=list(filter(lambda x: x.split('_')[0]=='Q16' ,df_NoQ.columns))
dfQ16=pd.DataFrame(df_NoQ[Q16_parts].stack().tolist(),columns=['MLFrameworks'])
dfQ16['MLFrameworks'].value_counts()

# %% [markdown]
# Majority use Scikit-learn Framework

# %%
l=sns.countplot(x='MLFrameworks',data=dfQ16,order=dfQ16['MLFrameworks'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ16['MLFrameworks'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-17 (Q17)

# %%
df_Q['Q17_Part_1']

# %%
Q17_parts=list(filter(lambda x: x.split('_')[0]=='Q17' ,df_NoQ.columns))
dfQ17=pd.DataFrame(df_NoQ[Q17_parts].stack().tolist(),columns=['MLAlgorithms'])
dfQ17['MLAlgorithms'].value_counts()

# %% [markdown]
# Majority use Linear or Logistic Regression ML Algorithms

# %%
l=sns.countplot(x='MLAlgorithms',data=dfQ17,order=dfQ17['MLAlgorithms'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ17['MLAlgorithms'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-18 (Q18)

# %%
df_Q['Q18_Part_1']

# %%
Q18_parts=list(filter(lambda x: x.split('_')[0]=='Q18' ,df_NoQ.columns))
dfQ18=pd.DataFrame(df_NoQ[Q18_parts].stack().tolist(),columns=['ComputerVision'])
dfQ18['ComputerVision'].value_counts()

# %% [markdown]
# Majority use Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc) Computer Vision method

# %%
l=sns.countplot(x='ComputerVision',data=dfQ18,order=dfQ18['ComputerVision'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ18['ComputerVision'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-19 (Q19)

# %%
 df_Q['Q19_Part_1']

# %%
Q19_parts=list(filter(lambda x: x.split('_')[0]=='Q19' ,df_NoQ.columns))
dfQ19=pd.DataFrame(df_NoQ[Q19_parts].stack().tolist(),columns=['NLP methods'])
dfQ19['NLP methods'].value_counts()

# %% [markdown]
# Majority use Word embeddings/vectors (GLoVe, fastText, word2vec) NLP method

# %%
l=sns.countplot(x='NLP methods',data=dfQ19,order=dfQ19['NLP methods'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ19['NLP methods'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-20 (Q20)

# %%
df_NoQ['Q20'].value_counts()

# %%
df_Q['Q20']

# %% [markdown]
# Majority belongs to Computer/Technology industry

# %%
l=sns.countplot(x='Q20',data=df_NoQ,order=df_NoQ['Q20'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q20'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-21 (Q21)

# %%
df_NoQ['Q21'].value_counts()

# %%
df_Q['Q21']

# %% [markdown]
# Majority have company size of 0-49 employees

# %%
l=sns.countplot(x='Q21',data=df_NoQ,order=df_NoQ['Q21'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q21'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-22 (Q22)

# %%
df_NoQ['Q22'].value_counts()

# %%
df_Q['Q22']

# %% [markdown]
# Majorly 1-2 people are responsible for data science

# %%
l=sns.countplot(x='Q22',data=df_NoQ,order=df_NoQ['Q22'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q22'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-23 (Q23)

# %%
df_NoQ['Q23'].value_counts()

# %%
df_Q['Q23']

# %% [markdown]
# Majorly they are exploring ML methods

# %%
l=sns.countplot(x='Q23',data=df_NoQ,order=df_NoQ['Q23'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q23'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-24 (Q24)

# %%
df_Q['Q24_Part_1']

# %%
Q24_parts=list(filter(lambda x: x.split('_')[0]=='Q24' ,df_NoQ.columns))
dfQ24=pd.DataFrame(df_NoQ[Q24_parts].stack().tolist(),columns=['Role'])
dfQ24['Role'].value_counts()

# %% [markdown]
# Majority analyze and understand data to influence product or business decisions

# %%
l=sns.countplot(x='Role',data=dfQ24,order=dfQ24['Role'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ24['Role'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-25 (Q25)

# %%
df_NoQ['Q25'].value_counts()

# %%
df_Q['Q25']

# %% [markdown]
# Majority have yearly compensation as $0-999

# %%
l=sns.countplot(x='Q25',data=df_NoQ,order=df_NoQ['Q25'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q25'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-26 (Q26)

# %%
df_NoQ['Q26'].value_counts()

# %%
df_Q['Q26']

# %% [markdown]
# Majority didn't spend on ML

# %%
l=sns.countplot(x='Q26',data=df_NoQ,order=df_NoQ['Q26'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q26'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-27

# %%
df_Q['Q27_A_Part_1']

# %%
Q27A_parts=list(filter(lambda x: (x.split('_')[0]=='Q27' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ27A=pd.DataFrame(df_NoQ[Q27A_parts].stack().tolist(),columns=['Cloud'])
dfQ27A['Cloud'].value_counts()

# %% [markdown]
# Majority use AWS platform for cloud computing

# %%
l=sns.countplot(x='Cloud',data=dfQ27A,order=dfQ27A['Cloud'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ27A['Cloud'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
df_Q['Q27_B_Part_1']

# %%
Q27B_parts=list(filter(lambda x: (x.split('_')[0]=='Q27' and x.split('_')[1]=='B') ,df_NoQ.columns))
dfQ27B=pd.DataFrame(df_NoQ[Q27B_parts].stack().tolist(),columns=['NextCloud'])
dfQ27B['NextCloud'].value_counts()

# %% [markdown]
# In Future, Majority hope AWS will be familiar Platform for Cloud Computing

# %%
l=sns.countplot(x='NextCloud',data=dfQ27B,order=dfQ27B['NextCloud'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ27B['NextCloud'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-28 (Q28)

# %%
df_NoQ['Q28'].value_counts()

# %%
df_Q['Q28']

# %% [markdown]
# Majority are familiar with AWS

# %%
l=sns.countplot(x='Q28',data=df_NoQ,order=df_NoQ['Q28'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q28'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-29

# %%
df_Q['Q29_A_Part_1']

# %%
Q29A_parts=list(filter(lambda x: (x.split('_')[0]=='Q29' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ29A=pd.DataFrame(df_NoQ[Q29A_parts].stack().tolist(),columns=['CloudProduct'])
dfQ29A['CloudProduct'].value_counts()

# %% [markdown]
# Majority use Amazon EC2 Product

# %%
l=sns.countplot(x='CloudProduct',data=dfQ29A,order=dfQ29A['CloudProduct'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ29A['CloudProduct'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
df_Q['Q29_B_Part_1']

# %%
Q29B_parts=list(filter(lambda x: (x.split('_')[0]=='Q29' and x.split('_')[1]=='B') ,df_NoQ.columns))
dfQ29B=pd.DataFrame(df_NoQ[Q29B_parts].stack().tolist(),columns=['CloudProdNext'])
dfQ29B['CloudProdNext'].value_counts()

# %% [markdown]
# In Future, Majority hope Google Cloud Compute Engine will be familiar product

# %%
l=sns.countplot(x='CloudProdNext',data=dfQ29B,order=dfQ29B['CloudProdNext'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ29B['CloudProdNext'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-30

# %%
df_Q['Q30_A_Part_1']

# %%
Q30A_parts=list(filter(lambda x: (x.split('_')[0]=='Q30' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ30A=pd.DataFrame(df_NoQ[Q30A_parts].stack().tolist(),columns=['Storage'])
dfQ30A['Storage'].value_counts()

# %% [markdown]
# Majority use Amazon S3 product

# %%
l=sns.countplot(x='Storage',data=dfQ30A,order=dfQ30A['Storage'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ30A['Storage'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-31

# %%
df_Q['Q31_A_Part_1']

# %%
Q31A_parts=list(filter(lambda x: (x.split('_')[0]=='Q31' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ31A=pd.DataFrame(df_NoQ[Q31A_parts].stack().tolist(),columns=['MLProducts'])
dfQ31A['MLProducts'].value_counts()

# %% [markdown]
# Majority don't use any ML Products

# %%
l=sns.countplot(x='MLProducts',data=dfQ31A,order=dfQ31A['MLProducts'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ31A['MLProducts'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
df_Q['Q31_B_Part_1']

# %%
Q31B_parts=list(filter(lambda x: (x.split('_')[0]=='Q31' and x.split('_')[1]=='B') ,df_NoQ.columns))
dfQ31B=pd.DataFrame(df_NoQ[Q31B_parts].stack().tolist(),columns=['MLProductsNext'])
dfQ31B['MLProductsNext'].value_counts()

# %% [markdown]
# In Future, Majority hope Google cloud vertex AI will be familiar

# %%
l=sns.countplot(x='MLProductsNext',data=dfQ31B,order=dfQ31B['MLProductsNext'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ31B['MLProductsNext'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-32

# %%
df_Q['Q32_A_Part_1']

# %%
Q32A_parts=list(filter(lambda x: (x.split('_')[0]=='Q32' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ32A=pd.DataFrame(df_NoQ[Q32A_parts].stack().tolist(),columns=['DataProducts'])
dfQ32A['DataProducts'].value_counts()

# %% [markdown]
# Majority use MySQL

# %%
l=sns.countplot(x='DataProducts',data=dfQ32A,order=dfQ32A['DataProducts'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ32A['DataProducts'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
df_Q['Q32_B_Part_1']

# %%
Q32B_parts=list(filter(lambda x: (x.split('_')[0]=='Q32' and x.split('_')[1]=='B') ,df_NoQ.columns))
dfQ32B=pd.DataFrame(df_NoQ[Q32B_parts].stack().tolist(),columns=['DataProductsNext'])
dfQ32B['DataProductsNext'].value_counts()

# %% [markdown]
# In Future, Majority hope MySQL will be familiar

# %%
l=sns.countplot(x='DataProductsNext',data=dfQ32B,order=dfQ32B['DataProductsNext'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ32B['DataProductsNext'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-33 (Q33)

# %%
df_NoQ['Q33'].value_counts()

# %%
df_Q['Q33']

# %% [markdown]
# Majority use MySQL

# %%
l=sns.countplot(x='Q33',data=df_NoQ,order=df_NoQ['Q33'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q33'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-34

# %%
df_Q['Q34_A_Part_2']

# %%
Q34A_parts=list(filter(lambda x: (x.split('_')[0]=='Q34' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ34A=pd.DataFrame(df_NoQ[Q34A_parts].stack().tolist(),columns=['BI'])
dfQ34A['BI'].value_counts()

# %% [markdown]
# Majority don't use any BI Tools

# %%
l=sns.countplot(x='BI',data=dfQ34A,order=dfQ34A['BI'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ34A['BI'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
df_Q['Q34_B_Part_1']

# %%
Q34B_parts=list(filter(lambda x: (x.split('_')[0]=='Q34' and x.split('_')[1]=='B') ,df_NoQ.columns))
dfQ34B=pd.DataFrame(df_NoQ[Q34B_parts].stack().tolist(),columns=['BINext'])
dfQ34B['BINext'].value_counts()

# %% [markdown]
# Majority expect Tableau as future used BI Tool

# %%
l=sns.countplot(x='BINext',data=dfQ34B,order=dfQ34B['BINext'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ34B['BINext'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-35 (Q35)

# %%
df_NoQ['Q35'].value_counts()

# %%
df_Q['Q35']

# %% [markdown]
# Majority use Microsoft Power BI

# %%
l=sns.countplot(x='Q35',data=df_NoQ,order=df_NoQ['Q35'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q35'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-36

# %%
df_Q['Q36_A_Part_1']

# %%
Q36A_parts=list(filter(lambda x: (x.split('_')[0]=='Q36' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ36A=pd.DataFrame(df_NoQ[Q36A_parts].stack().tolist(),columns=['AutoML'])
dfQ36A['AutoML'].value_counts()

# %% [markdown]
# Majority don't use any Auto ML

# %%
l=sns.countplot(x='AutoML',data=dfQ36A,order=dfQ36A['AutoML'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ36A['AutoML'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
df_Q['Q36_B_Part_1']

# %%
Q36B_parts=list(filter(lambda x: (x.split('_')[0]=='Q36' and x.split('_')[1]=='B') ,df_NoQ.columns))
dfQ36B=pd.DataFrame(df_NoQ[Q36B_parts].stack().tolist(),columns=['AutoMLNext'])
dfQ36B['AutoMLNext'].value_counts()

# %% [markdown]
# Majority expect Automated model selection followed by Automation of full ML pipelines will be used in Future

# %%
l=sns.countplot(x='AutoMLNext',data=dfQ36B,order=dfQ36B['AutoMLNext'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ36B['AutoMLNext'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-37

# %%
df_Q['Q37_A_Part_1']

# %%
Q37A_parts=list(filter(lambda x: (x.split('_')[0]=='Q37' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ37A=pd.DataFrame(df_NoQ[Q37A_parts].stack().tolist(),columns=['AutoMLTools'])
dfQ37A['AutoMLTools'].value_counts()

# %% [markdown]
# Majority don't use Auto ML Tools

# %%
l=sns.countplot(x='AutoMLTools',data=dfQ37A,order=dfQ37A['AutoMLTools'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ37A['AutoMLTools'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
df_Q['Q37_B_Part_1']

# %%
Q37B_parts=list(filter(lambda x: (x.split('_')[0]=='Q37' and x.split('_')[1]=='B') ,df_NoQ.columns))
dfQ37B=pd.DataFrame(df_NoQ[Q37B_parts].stack().tolist(),columns=['AutoMLToolsNext'])
dfQ37B['AutoMLToolsNext'].value_counts()

# %% [markdown]
# Majority expect Google cloud AutoML Tool will be used in future

# %%
l=sns.countplot(x='AutoMLToolsNext',data=dfQ37B,order=dfQ37B['AutoMLToolsNext'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ37B['AutoMLToolsNext'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-38

# %%
df_Q['Q38_A_Part_2']

# %%
Q38A_parts=list(filter(lambda x: (x.split('_')[0]=='Q38' and x.split('_')[1]=='A') ,df_NoQ.columns))
dfQ38A=pd.DataFrame(df_NoQ[Q38A_parts].stack().tolist(),columns=['MLTools'])
dfQ38A['MLTools'].value_counts()

# %% [markdown]
# Majority don't use ML Tools

# %%
l=sns.countplot(x='MLTools',data=dfQ38A,order=dfQ38A['MLTools'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ38A['MLTools'].value_counts().sort_index().index,rotation=90)
plt.show()

# %%
df_Q['Q38_B_Part_1']

# %%
Q38B_parts=list(filter(lambda x: (x.split('_')[0]=='Q38' and x.split('_')[1]=='B') ,df_NoQ.columns))
dfQ38B=pd.DataFrame(df_NoQ[Q38B_parts].stack().tolist(),columns=['MLToolsNext'])
dfQ38B['MLToolsNext'].value_counts()

# %% [markdown]
# Majority expect TensorBoard as future ML Tool

# %%
l=sns.countplot(x='MLToolsNext',data=dfQ38B,order=dfQ38B['MLToolsNext'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ38B['MLToolsNext'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-39 (Q39)

# %%
df_Q['Q39_Part_4']

# %%
Q39_parts=list(filter(lambda x: x.split('_')[0]=='Q39' ,df_NoQ.columns))
dfQ39=pd.DataFrame(df_NoQ[Q39_parts].stack().tolist(),columns=['Sharing'])
dfQ39['Sharing'].value_counts()

# %% [markdown]
# Majority shares in Github

# %%
l=sns.countplot(x='Sharing',data=dfQ39,order=dfQ39['Sharing'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ39['Sharing'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-40 (Q40)

# %%
df_Q['Q40_Part_1']

# %%
Q40_parts=list(filter(lambda x: x.split('_')[0]=='Q40' ,df_NoQ.columns))
dfQ40=pd.DataFrame(df_NoQ[Q40_parts].stack().tolist(),columns=['Platform'])
dfQ40['Platform'].value_counts()

# %% [markdown]
# Majority use Coursera Platform

# %%
l=sns.countplot(x='Platform',data=dfQ40,order=dfQ40['Platform'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ40['Platform'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-41 (Q41)

# %%
df_NoQ['Q41'].value_counts()

# %%
df_Q['Q41']

# %% [markdown]
# Majority use Basic statistical software (Microsoft Excel, Google Sheets, etc.)

# %%
l=sns.countplot(x='Q41',data=df_NoQ,order=df_NoQ['Q41'].value_counts().sort_index().index)
l.set_xticklabels(labels=df_NoQ['Q41'].value_counts().sort_index().index,rotation=90)
plt.show()

# %% [markdown]
# Question-42 (Q42)

# %%
df_Q['Q42_Part_1']

# %%
Q42_parts=list(filter(lambda x: x.split('_')[0]=='Q42' ,df_NoQ.columns))
dfQ42=pd.DataFrame(df_NoQ[Q42_parts].stack().tolist(),columns=['Media'])
dfQ42['Media'].value_counts()

# %% [markdown]
# Majority have Kaggle (notebooks, forums, etc) as Favorite media source

# %%
l=sns.countplot(x='Media',data=dfQ42,order=dfQ42['Media'].value_counts().sort_index().index)
l.set_xticklabels(labels=dfQ42['Media'].value_counts().sort_index().index,rotation=90)
plt.show()
