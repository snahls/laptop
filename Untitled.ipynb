# %%
import tweepy
import pandas as pd
consumer_key="F2xoihNRNGPGqZWJlstb0kHuS"
consumer_secret="Cx32yanebJLE3Nqp0RkBG3YnJkeDqSE9QcqLS9LR2g5qyMmELp"
access_token="1276766738063872000-1J9Hpv03DHsxKcyqTMgJsUXefZLzpA"
access_token_secret="vS6sDgOLdUlWTTtKNmPQ4WcnPIvy57hvpIfcKGrR5dkIC"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
import tweepy
import pandas as pd
import csv

consumer_key="F2xoihNRNGPGqZWJlstb0kHuS"
consumer_secret="Cx32yanebJLE3Nqp0RkBG3YnJkeDqSE9QcqLS9LR2g5qyMmELp"
access_token="1276766738063872000-1J9Hpv03DHsxKcyqTMgJsUXefZLzpA"
access_token_secret="vS6sDgOLdUlWTTtKNmPQ4WcnPIvy57hvpIfcKGrR5dkIC"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

tweets_locs=[]

birthday = ['#happybd','#birthday','#happybirthday','#hbd','#bday']
child = ["#birth", "#childbirth", "#christening", "#childbearing", '#newparents', '#newborn']
marriage = ["#marriage", "#wedding", "#announcements", "#marriagegoals", "#hooked"]
vacation = ["#vacation", "#islandlife", "#travel", "#travelphotography", "#holidays", "#roadtrip", "#trip", "#adventure"]
graduation = ["#graduation", "#graduationday", "#graduate", "#graduating", '#convocation', '#graduated', '#graduationceremony'] 
career = ["#careergoals", "#newjob", "#gothired", "#firstdayfeeling", '#jobpromotion', '#firstdayjob', '#changingjob', '#newlyemployed']
relocation = ["#movingto", "#housing", "#relocate", "#relocation", '#newhome', '#newapartment', '#movinghouse', '#homeowner']
death = ['#saddemise', '#restinpeace', '#rip', '#passedaway', '#death']
divorce = ['#divorce', '#separated', '#divorced']
awards = ['#winningmoment', '#awarded', '#awardsandrewards', '#awardsandrecognition']
layoff = ['#furlough', '#layoff', '#dismissal']
education = ['#firstdayschool', '#kidscollege', '#kindergarten']
purchases = ['#newpurchase', '#newcar']
medical = ['#medicalemergency', '#hospitalized']
events = ['#publicevent', '#politicalevent', '#fundraising', '#charity']

for i in child:
  choice= i + "-filter:retweets"
  tweets = tweepy.Cursor(api.search_tweets,q=choice,lang="en",tweet_mode='extended').items(20000)
  for tweet in tweets:
    for media in tweet.entities.get("media",[{}]):
      if media.get("type",None) == "photo":
        continue
      elif media.get("type",None) == "video":
        continue
      else:
        tweets_locs.append([tweet.id,tweet.full_text,tweet.author,tweet.created_at,tweet.entities,tweet.geo,tweet.lang,tweet.in_reply_to_screen_name,tweet.in_reply_to_status_id,tweet.in_reply_to_user_id,tweet.retweet,tweet.retweet_count,tweet.retweets,tweet.retweeted,tweet.source,tweet.source_url,tweet.user,tweet.user.screen_name,tweet.user.url,tweet.user.translator_type,tweet.user.timeline,tweet.user.time_zone,tweet.user.name,tweet.user.lang,tweet.user.is_translator,tweet.user.is_translation_enabled,tweet.user.id,tweet.user.geo_enabled,tweet.user.entities, tweet.user.location]) 

tweet_text = pd.DataFrame(data=tweets_locs,columns=['id','text','author','created_at','entities','geo','lang','in_reply_to_screen_name','in_reply_to_status_id','in_reply_to_user_id','retweet','retweet_count','retweets','retweeted','source','source_url','user','user_screen_name','user_url','user_translator_type','user_timeline','user_time_zone','user_name','user_lang','user_is_translator','user_is_translation_enabled','user_id','user_geo_enabled','user_entities', 'user_location'])
tweet_text.to_csv("child_2.csv",index=False,sep=',',quoting=csv.QUOTE_NONNUMERIC)
print('Done')
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~\.conda\envs\LifeEvent\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# ~\.conda\envs\LifeEvent\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\.conda\envs\LifeEvent\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\.conda\envs\LifeEvent\lib\site-packages\urllib3\connection.py in connect(self)
#     425             ssl_context=context,
# --> 426             tls_in_tls=tls_in_tls,
#     427         )
#
# ~\.conda\envs\LifeEvent\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     449         ssl_sock = _ssl_wrap_socket_impl(
# --> 450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#
# ~\.conda\envs\LifeEvent\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# ~\.conda\envs\LifeEvent\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     422             context=self,
# --> 423             session=session
#     424         )
#
# ~\.conda\envs\LifeEvent\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#
# ~\.conda\envs\LifeEvent\lib\ssl.py in do_handshake(self, block)
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#
# SSLError: [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:1091)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\.conda\envs\LifeEvent\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\.conda\envs\LifeEvent\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# ~\.conda\envs\LifeEvent\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=%23birth-filter%3Aretweets&max_id=1475860965967159304&lang=en&tweet_mode=extended (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:1091)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     218                         data=post_data, files=files, json=json_payload,
# --> 219                         timeout=self.timeout, auth=auth, proxies=self.proxy
#     220                     )
#
# ~\.conda\envs\LifeEvent\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~\.conda\envs\LifeEvent\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#
# ~\.conda\envs\LifeEvent\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#
# SSLError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=%23birth-filter%3Aretweets&max_id=1475860965967159304&lang=en&tweet_mode=extended (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:1091)')))
#
# During handling of the above exception, another exception occurred:
#
# TweepyException                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17940/4214605329.py in <module>
#      33   choice= i + "-filter:retweets"
#      34   tweets = tweepy.Cursor(api.search_tweets,q=choice,lang="en",tweet_mode='extended').items(20000)
# ---> 35   for tweet in tweets:
#      36     for media in tweet.entities.get("media",[{}]):
#      37       if media.get("type",None) == "photo":
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\api.py in search_tweets(self, q, **kwargs)
#    1270                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1271                 'until', 'since_id', 'max_id', 'include_entities'
# -> 1272             ), q=q, **kwargs
#    1273         )
#    1274
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     220                     )
#     221                 except Exception as e:
# --> 222                     raise TweepyException(f'Failed to send request: {e}').with_traceback(sys.exc_info()[2])
#     223
#     224                 if 200 <= resp.status_code < 300:
#
# ~\.conda\envs\LifeEvent\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     217                         method, url, params=params, headers=headers,
#     218                         data=post_data, files=files, json=json_payload,
# --> 219                         timeout=self.timeout, auth=auth, proxies=self.proxy
#     220                     )
#     221                 except Exception as e:
#
# ~\.conda\envs\LifeEvent\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\.conda\envs\LifeEvent\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\.conda\envs\LifeEvent\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# TweepyException: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=%23birth-filter%3Aretweets&max_id=1475860965967159304&lang=en&tweet_mode=extended (Caused by SSLError(SSLError(1, '[SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:1091)')))

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\ls59581\\Desktop\\Hashtags\\Label1\\dv1.csv')
df.tail()
# Out:
#                        id                                               text  \
# 1172  1470177821775610000  man FMA really was fucking stacked with wife g...
# 1173  1470176750579730000  @thefinal_pam ETERNALLY!!! god i love him so m...
# 1174  1470173775199150000  van hohenheim did kind of invent being married...
# 1175  1470173679447430000  watching a retrospective on FMA and being remi...
# 1176  1470169315408290000  I been getting too many Dennnys patty Melts fr...
#
#            label person_type relation
# 1172  irrelevant         NaN      NaN
# 1173  irrelevant         NaN      NaN
# 1174  irrelevant         NaN      NaN
# 1175  irrelevant         NaN      NaN
# 1176  irrelevant         NaN      NaN

# %%
df1=df[df['label']!='irrelevant']
df1.shape
# Out:
# (984, 5)

# %%
df1.index+=2

# %%
import csv
df1.to_csv('dv2.csv',sep=',',quoting=csv.QUOTE_NONNUMERIC)

# %%
df3=df2[df2['text'].str.contains('blog')]

# %%
df=pd.read_csv('C:\\Users\\ls59581\\Desktop\\Hashtags\\Label1\\b1.csv')
df.shape
# Out:
# (6738, 5)

# %%
df['label']='irrelevant'

# %%
import csv
df.to_csv('r1.csv',index=False,sep=',',quoting=csv.QUOTE_NONNUMERIC)

# %%
df.isnull().sum()
# Out:
# id                0
# text              0
# label             0
# person_type    5754
# relation       6452
# dtype: int64

# %%
df[df['relation']=='mother/self']
# Out:
#                        id                                               text  \
# 1215  1472135154047070000  Grateful for small things, big things and ever...
#
#          label person_type     relation
# 1215  birthday      second  mother/self

# %%
df['relation'].value_counts()
# Out:
# daughter               47
# son                    44
# brother                40
# mother                 37
# father                 25
# sister                 24
# wife                   21
# nephew                 11
# niece                  10
# husband                 7
# grand mother            4
# uncle                   4
# mother-in-law           2
# grand father            2
# aunt                    2
# father/grand father     1
# mother/self             1
# father-in-law           1
# brother-in-law          1
# grand son               1
# grand children          1
# Name: relation, dtype: int64

# %%
df.iloc[[1127,1361],[2,3,4]]=['birthday','second','sister']

# %%
df['person_type'].isnull().sum()
# Out:
# 6519

# %%
import csv
df1.to_csv('b11.csv',sep=',',quoting=csv.QUOTE_NONNUMERIC)

# %%
df['label'].values[39]='death'

# %%
df['person_type'].values[39]='second'

# %%
df['relation'].values[39]='father'

# %%
df[['label','person_type','relation']].head(49)
# Out:
#          label person_type       relation
# 0   irrelevant
# 1   irrelevant
# 2   irrelevant
# 3   irrelevant
# 4   irrelevant
# 5   irrelevant
# 6   irrelevant
# 7   irrelevant
# 8   irrelevant
# 9   irrelevant
# 10  irrelevant
# 11       death      second  father-in-law
# 12  irrelevant
# 13  irrelevant
# 14  irrelevant
# 15  irrelevant
# 16  irrelevant
# 17  irrelevant
# 18  irrelevant
# 19  irrelevant
# 20  irrelevant
# 21  irrelevant
# 22  irrelevant
# 23  irrelevant
# 24  irrelevant
# 25  irrelevant
# 26    birthday      second         father
# 27  irrelevant
# 28  irrelevant
# 29  irrelevant
# 30  irrelevant
# 31  irrelevant
# 32  irrelevant
# 33  irrelevant
# 34  irrelevant
# 35  irrelevant
# 36  irrelevant
# 37  irrelevant
# 38  irrelevant
# 39       death      second         father
# 40  irrelevant
# 41  irrelevant
# 42  irrelevant
# 43  irrelevant
# 44  irrelevant
# 45  irrelevant
# 46  irrelevant
# 47  irrelevant
# 48  irrelevant

# %%
df[['label','person_type','relation']]=['irrelevant','','']
df.shape
# Out:
# (6684, 33)

# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\ls59581\\Desktop\\Hashtags\\New2\\marriage_2.csv')
df.shape
# Out:
# (3537, 30)

# %%
f=df[['id','text']]

# %%
f['label']='irrelevant'
# Out:
# C:\Users\ls59581\AppData\Local\Temp/ipykernel_25164/3708098673.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['label']='irrelevant'

# %%
f.head()
# Out:
#                     id                                               text  \
# 0  1476906194165911552  Preservation: "Shades of Steinbeck" #shortstor...
# 1  1476900453875126275  #marriage #loud Poetry sounding prose style si...
# 2  1476900250665336833  Having troubles in your #marriage? If so, chec...
# 3  1476898692502364168  #jokesday #jokerit #MarriageEquaility 1 author...
# 4  1476894947387322370  A good wife and a good book are very similar. ...
#
#         label
# 0  irrelevant
# 1  irrelevant
# 2  irrelevant
# 3  irrelevant
# 4  irrelevant

# %%
import csv
f.to_csv('m2.csv',index=False,sep=',',quoting=csv.QUOTE_NONNUMERIC)

# %%
df.to_csv('birthdayd.csv',index=False,sep=',',quoting=csv.QUOTE_NONNUMERIC)

# %%
import pandas as pd
df1=pd.read_csv('New folder/death_2.csv')
df1.shape
# Out:
# (9505, 30)

# %%
df['text'].values[6130]
# Out:
# "Been dreading today for ages. This time last year I was saying goodbye to my fil, kev, after a horrible horrible week. I'm feeling OK today. No urge to use or drink. I'm learning to sit with my feelings a bit more. I miss the old bugger 💛🧡 #RecoveryPosse #COVID19 #RIP"

# %%
df['label']='irrelevant'

# %%
# Out:
#                     id                                               text  \
# 0  1476921879998910465  Respected Wisdom // #🕊✝️\n\n.\n.\n.\n\n#Archbi...
# 1  1476875475708428301  finally finished watching seunging car vlive w...
# 2  1476874266473807878  RIP Bluenoses \n\n#RestinPeace #BCFC #KRO http...
# 3  1476856820354457602  #RIP #RestinPeace #sendinglove #love #thankyou...
# 4  1476856791157907476  @CIA #RIP #RestinPeace #sendinglove #love #tha...
#
#                                               author           created_at  \
# 0  User(_api=<tweepy.api.API object at 0x7f672d60...  2021-12-31 14:23:10
# 1  User(_api=<tweepy.api.API object at 0x7f672d60...  2021-12-31 11:18:47
# 2  User(_api=<tweepy.api.API object at 0x7f672d60...  2021-12-31 11:13:58
# 3  User(_api=<tweepy.api.API object at 0x7f672d60...  2021-12-31 10:04:39
# 4  User(_api=<tweepy.api.API object at 0x7f672d60...  2021-12-31 10:04:32
#
#                                             entities  geo lang  \
# 0  {'hashtags': [{'text': 'ArchbishopDesmondTutu'...  NaN   en
# 1  {'hashtags': [{'text': 'RestInPeace', 'indices...  NaN   en
# 2  {'hashtags': [{'text': 'RestinPeace', 'indices...  NaN   en
# 3  {'hashtags': [{'text': 'RIP', 'indices': [0, 4...  NaN   en
# 4  {'hashtags': [{'text': 'RIP', 'indices': [5, 9...  NaN   en
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_user_id  ...  \
# 0                     NaN                    NaN                  NaN  ...
# 1                     NaN                    NaN                  NaN  ...
# 2                     NaN                    NaN                  NaN  ...
# 3                     NaN                    NaN                  NaN  ...
# 4                     CIA           1.476554e+18         2.359926e+09  ...
#
#                                        user_timeline  user_time_zone  \
# 0  <bound method User.timeline of User(_api=<twee...             NaN
# 1  <bound method User.timeline of User(_api=<twee...             NaN
# 2  <bound method User.timeline of User(_api=<twee...             NaN
# 3  <bound method User.timeline of User(_api=<twee...             NaN
# 4  <bound method User.timeline of User(_api=<twee...             NaN
#
#                                  user_name  user_lang user_is_translator  \
# 0                     Rouén D. E. Robinson        NaN              False
# 1                                  (~‾▿‾)~        NaN              False
# 2                         Blues Collective        NaN              False
# 3  Kelsey Marie Bell She/her or them/their        NaN              False
# 4  Kelsey Marie Bell She/her or them/their        NaN              False
#
#   user_is_translation_enabled              user_id user_geo_enabled  \
# 0                       False             62439795             True
# 1                       False  1359314354299043840            False
# 2                       False            546821018             True
# 3                       False  1441559488075468812             True
# 4                       False  1441559488075468812             True
#
#                                        user_entities        user_location
# 0  {'url': {'urls': [{'url': 'https://t.co/WyHjTQ...  Grand Bahama Island
# 1                      {'description': {'urls': []}}                   17
# 2  {'url': {'urls': [{'url': 'https://t.co/x7ZfyA...           Birmingham
# 3  {'url': {'urls': [{'url': 'https://t.co/oLyYJx...                  NaN
# 4  {'url': {'urls': [{'url': 'https://t.co/oLyYJx...                  NaN
#
# [5 rows x 30 columns]

# %%
df.isnull().sum()
# Out:
# id       0
# text     0
# label    0
# dtype: int64

# %%
import csv
df.to_csv('b1.csv',index=False,sep=',',quoting=csv.QUOTE_NONNUMERIC)

# %%
filter=pd.concat([filter,f[f['text'].str.contains('husband')]],axis=0)
